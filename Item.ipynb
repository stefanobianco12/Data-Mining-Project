# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import math

# %%
df = pd.read_csv('D:/Desktop/DataMining/new_Basket_2.csv', sep=',')
df
# Out:
#                Country  Customer ID                          Description  \
# 0       United Kingdom      13085.0  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1       United Kingdom      13085.0                   PINK CHERRY LIGHTS
# 2       United Kingdom      13085.0                  WHITE CHERRY LIGHTS
# 3       United Kingdom      13085.0       STRAWBERRY CERAMIC TRINKET BOX
# 4       United Kingdom      13085.0           PINK DOUGHNUT TRINKET POT
# ...                ...          ...                                  ...
# 878447          France      12680.0          PACK OF 20 SPACEBOY NAPKINS
# 878448          France      12680.0         CHILDREN'S APRON DOLLY GIRL
# 878449          France      12680.0        CHILDRENS CUTLERY DOLLY GIRL
# 878450          France      12680.0      CHILDRENS CUTLERY CIRCUS PARADE
# 878451          France      12680.0        BAKING SET 9 PIECE RETROSPOT
#
#         Invoice          InvoiceDate  Price  Quantity StockCode
# ...

# %%
#Tot of item purchased ordered by "most purchased Item"
TotItemBought = df.groupby('StockCode', as_index=False)['Quantity'].sum()
TotItemBought.columns = ['StockCode', 'TotItemBought']
#TotItem.sort_values(by=['TotItem'], ascending=False)
TotItemBought
# Out:
#          StockCode  TotItemBought
# 0            10002           2597
# 1           10002R              4
# 2            10080            289
# 3            10109              4
# 4            10120            244
# ...            ...            ...
# 4715  gift_0001_60             13
# 4716  gift_0001_70             12
# 4717  gift_0001_80             12
# 4718  gift_0001_90             12
# 4719             m              5
#
# [4720 rows x 2 columns]

# %%
df.dtypes
# Out:
# Country         object
# Customer ID    float64
# Description     object
# Invoice          int64
# InvoiceDate     object
# Price          float64
# Quantity         int64
# StockCode       object
# dtype: object

# %%
#Number of distinct customer for Item
DistinctCust = df.groupby('StockCode')['Customer ID'].nunique().reset_index()
DistinctCust.columns = ['StockCode', 'DistinctCust']
DistinctCust
# Out:
#          StockCode  DistinctCust
# 0            10002           152
# 1           10002R             1
# 2            10080            24
# 3            10109             1
# 4            10120            42
# ...            ...           ...
# 4715  gift_0001_60             1
# 4716  gift_0001_70             1
# 4717  gift_0001_80             1
# 4718  gift_0001_90             1
# 4719             m             1
#
# [4720 rows x 2 columns]

# %%
#The number of distinct session where an Item was bought 
DistinctSession = df.groupby('StockCode')['Invoice'].nunique().reset_index()
DistinctSession.columns = ['StockCode', 'DistinctSession']
DistinctSession
# Out:
#          StockCode  DistinctSession
# 0            10002              314
# 1           10002R                3
# 2            10080               27
# 3            10109                1
# 4            10120               60
# ...            ...              ...
# 4715  gift_0001_60                2
# 4716  gift_0001_70                2
# 4717  gift_0001_80                2
# 4718  gift_0001_90                2
# 4719             m                4
#
# [4720 rows x 2 columns]

# %%
#Verifico che 10002R sia stato acquistato in 3 sessioni dallo stesso Customer
mask=df['StockCode']=='10002R'
fii=df[mask]
print(fii)
# Out:
#               Country  Customer ID            Description  Invoice  \
# 4407   United Kingdom      17841.0  ROBOT PENCIL SHARPNER   489857
# 34016  United Kingdom      17841.0  ROBOT PENCIL SHARPNER   492783
# 57858  United Kingdom      17841.0  ROBOT PENCIL SHARPNER   495574
#
#                InvoiceDate  Price  Quantity StockCode
# 4407   2009-02-12 14:43:00   5.17         1    10002R
# 34016  2009-12-18 17:15:00   5.17         2    10002R
# 57858  2010-01-25 17:36:00   5.06         1    10002R

# %%
#Mean Item bought for Month
MeanItemMonth = df.groupby('StockCode', as_index=False)['Quantity'].sum()
MeanItemMonth.columns = ['StockCode', 'MeanItemMonth']
MeanItemMonth['MeanItemMonth'] = MeanItemMonth['MeanItemMonth']/36
MeanItemMonth
# Out:
#          StockCode  MeanItemMonth
# 0            10002      72.138889
# 1           10002R       0.111111
# 2            10080       8.027778
# 3            10109       0.111111
# 4            10120       6.777778
# ...            ...            ...
# 4715  gift_0001_60       0.361111
# 4716  gift_0001_70       0.333333
# 4717  gift_0001_80       0.333333
# 4718  gift_0001_90       0.333333
# 4719             m       0.138889
#
# [4720 rows x 2 columns]

# %%
#mean of item bought for session (totItem/nsess)
AvgItemSess =TotItemBought.merge(DistinctSession, on='StockCode').set_index('StockCode')
AvgItemSess['AvgItemSess']=AvgItemSess['TotItemBought']/AvgItemSess['DistinctSession']
AvgItemSess
# Out:
#               TotItemBought  DistinctSession  AvgItemSess
# StockCode
# 10002                  2597              314     8.270701
# 10002R                    4                3     1.333333
# 10080                   289               27    10.703704
# 10109                     4                1     4.000000
# 10120                   244               60     4.066667
# ...                     ...              ...          ...
# gift_0001_60             13                2     6.500000
# gift_0001_70             12                2     6.000000
# gift_0001_80             12                2     6.000000
# gift_0001_90             12                2     6.000000
# m                         5                4     1.250000
#
# [4720 rows x 3 columns]

# %%
MeanTimeGap = df.groupby(['StockCode', 'InvoiceDate'], as_index=False)['Invoice'].count()
MeanTimeGap.columns = ['StockCode', 'InvoiceDate','MeanTimeGap']
MeanTimeGap
MeanTimeGap['InvoiceDate'] = pd.to_datetime(MeanTimeGap['InvoiceDate']).dt.date

# %%
#ogni quanto è stato acquistato un item (n giorni)
def gapTime(MeanTimeGap):
    mean_time_gap=[]
    for item in MeanTimeGap['StockCode'].unique():
        df_aux=MeanTimeGap[MeanTimeGap['StockCode']==item]
        df_aux=df_aux['InvoiceDate'].to_list()
        sum_diff_gap = 0
        for i in range(0, len(df_aux)-1):
            sum_diff_gap += (df_aux[i+1]-df_aux[i]).days

        if len(df_aux)-1 == 0:
            mean_time_gap.append(0)
        else:
            mean_time_gap.append(sum_diff_gap / (len(df_aux)-1))
    return mean_time_gap

# %%
MeanTimeGap
# Out:
#            StockCode InvoiceDate  MeanTimeGap
# 0              10002  2009-01-12            1
# 1              10002  2009-03-12            1
# 2              10002  2009-03-12            1
# 3              10002  2009-03-12            1
# 4              10002  2009-04-12            1
# ...              ...         ...          ...
# 864985  gift_0001_90  2010-09-08            1
# 864986             m  2010-02-19            2
# 864987             m  2010-04-13            1
# 864988             m  2010-08-06            1
# 864989             m  2010-12-21            1
#
# [864990 rows x 3 columns]

# %%
mean_time_gap=gapTime(MeanTimeGap)

# %%
item=MeanTimeGap['StockCode'].unique()
data_tuples = list(zip(item,mean_time_gap))
MeanTime=pd.DataFrame(data_tuples, columns=['StockCode','MeanTimeGap'])
MeanTime

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], errors='coerce')

# %%
mean_time_gap

# %%
Item =DistinctCust.merge(AvgItemSess, on='StockCode').merge(MeanItemMonth, on='StockCode').set_index('StockCode')

# %%
Item
# Out:
#               DistinctCust  TotItemBought  DistinctSession  AvgItemSess  \
# StockCode
# 10002                  152           2597              314     8.270701
# 10002R                   1              4                3     1.333333
# 10080                   24            289               27    10.703704
# 10109                    1              4                1     4.000000
# 10120                   42            244               60     4.066667
# ...                    ...            ...              ...          ...
# gift_0001_60             1             13                2     6.500000
# gift_0001_70             1             12                2     6.000000
# gift_0001_80             1             12                2     6.000000
# gift_0001_90             1             12                2     6.000000
# m                        1              5                4     1.250000
#
#               MeanItemMonth
# StockCode
# 10002             72.138889
# ...

# %%
df=Item
df.to_csv('D:/Desktop/DataMining/Item.csv')

# %%
#Description
gb2=df.groupby(['StockCode','Description']).nunique().reset_index()
gb2
# Out:
#          StockCode                  Description  Country  Customer ID  \
# 0            10002  INFLATABLE POLITICAL GLOBE        12          152
# 1           10002R        ROBOT PENCIL SHARPNER        1            1
# 2            10080     GROOVY CACTUS INFLATABLE        1           24
# 3            10080                        check        1            1
# 4            10109         BENDY COLOUR PENCILS        1            1
# ...            ...                          ...      ...          ...
# 6140  gift_0001_60                            0        1            1
# 6141  gift_0001_70                            0        1            1
# 6142  gift_0001_80                            0        1            1
# 6143  gift_0001_90                            0        1            1
# 6144             m                       Manual        1            1
#
#       Invoice  InvoiceDate  Price  Quantity  Categoria
# 0         314          312      5        20          1
# ...

# %%
#if df['Description']== 1 is 'BAG' in  

#B_filter =df.filter(regex='(BAG)')
#df.query('Description == @B_filter')

S= df.groupby('Description', as_index=False)
S.str.contains('^BAG.*')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16908/1794659746.py in <module>
#       5
#       6 S= df.groupby('Description', as_index=False)
# ----> 7 S.str.contains('^BAG.*')
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     909             return self[attr]
#     910
# --> 911         raise AttributeError(
#     912             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     913         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'str'

# %%
#Setto le categorie a seconda della parola ricercata
a=df[df['Description'].str.contains('LIGHTS*')]
Light = a.groupby('StockCode')['Categoria'].nunique().reset_index()
Light.columns = ['StockCode', 'Category']
Light["Category"]=2
Light

#df["Categoria"] = ""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16908/1233530830.py in <module>
#       1 #Setto le categorie a seconda della parola ricercata
# ----> 2 a=df[df['Description'].str.contains('LIGHTS*')]
#       3 Light = a.groupby('StockCode')['Categoria'].nunique().reset_index()
#       4 Light.columns = ['StockCode', 'Category']
#       5 Light["Category"]=2
#
# ~\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3446
#    3447         # Do we have a (boolean) 1d indexer?
# -> 3448         if com.is_bool_indexer(key):
#    3449             return self._getitem_bool_array(key)
#    3450
#
# ~\Anaconda\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     137                     # Don't raise on e.g. ["A", "B", np.nan], see
# ...

# %%
a=df[df['Description'].str.contains('DOG*')]
DOG= a.groupby('StockCode')['Categoria'].nunique().reset_index()
DOG.columns = ['StockCode', 'Category']
DOG["Category"]=4
DOG
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16908/3112538955.py in <module>
# ----> 1 a=df[df['Description'].str.contains('DOG*')]
#       2 DOG= a.groupby('StockCode')['Categoria'].nunique().reset_index()
#       3 DOG.columns = ['StockCode', 'Category']
#       4 DOG["Category"]=4
#       5 DOG
#
# ~\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3446
#    3447         # Do we have a (boolean) 1d indexer?
# -> 3448         if com.is_bool_indexer(key):
#    3449             return self._getitem_bool_array(key)
#    3450
#
# ~\Anaconda\lib\site-packages\pandas\core\common.py in is_bool_indexer(key)
#     137                     # Don't raise on e.g. ["A", "B", np.nan], see
#     138                     #  test_loc_getitem_list_of_labels_categoricalindex_with_na
# ...

# %%
a=df[df['Description'].str.contains('CHILD*')]
CHILD= a.groupby('StockCode')['Categoria'].nunique().reset_index()
CHILD.columns = ['StockCode', 'Category']
CHILD["Category"]=16
CHILD
# Out:
#    StockCode  Category
# 0      20680        16
# 1      20681        16
# 2      20682        16
# 3      20683        16
# 4      20684        16
# ..       ...       ...
# 56    84997D        16
# 57    84997a        16
# 58    84997b        16
# 59    84997c        16
# 60    84997d        16
#
# [61 rows x 2 columns]

# %%
a=df[df['Description'].str.contains('DECORATION*')]
decoration= a.groupby('StockCode')['Categoria'].nunique().reset_index()
decoration.columns = ['StockCode', 'Category']
decoration["Category"]=5
decoration
# Out:
#     StockCode  Category
# 0       16239         5
# 1       20668         5
# 2       20707         5
# 3       20814         5
# 4       21007         5
# ..        ...       ...
# 131     85081         5
# 132    85086A         5
# 133     85112         5
# 134     85212         5
# 135     85213         5
#
# [136 rows x 2 columns]

# %%
a=df[df['Description'].str.contains('PEN*')]
PEN= a.groupby('StockCode')['Categoria'].nunique().reset_index()
PEN.columns = ['StockCode', 'Category']
PEN["Category"]=6
PEN
# Out:
#     StockCode  Category
# 0      10002R         6
# 1       10109         6
# 2      10123C         6
# 3      10123G         6
# 4      10124A         6
# ..        ...       ...
# 436    90164A         6
# 437    90164B         6
# 438    90165A         6
# 439    90165B         6
# 440  DCGS0041         6
#
# [441 rows x 2 columns]

# %%
a=df[df['Description'].str.contains('FLOWER*')]
FLOWER= a.groupby('StockCode')['Categoria'].nunique().reset_index()
FLOWER.columns = ['StockCode', 'Category']
FLOWER["Category"]=7
FLOWER
# Out:
#     StockCode  Category
# 0      16151A         7
# 1      16256B         7
# 2      17011A         7
# 3      17011B         7
# 4      17011C         7
# ..        ...       ...
# 203    90202A         7
# 204    90202B         7
# 205    90202C         7
# 206    90202D         7
# 207     90208         7
#
# [208 rows x 2 columns]

# %%
a=df[df['Description'].str.contains('DESIGN*')]
DESIGN= a.groupby('StockCode')['Categoria'].nunique().reset_index()
DESIGN.columns = ['StockCode', 'Category']
DESIGN["Category"]=8
DESIGN
# Out:
#     StockCode  Category
# 0       10125         8
# 1       11001         8
# 2      15058C         8
# 3      15060B         8
# 4      15060b         8
# ..        ...       ...
# 144     84826         8
# 145     84934         8
# 146     85060         8
# 147    85160A         8
# 148    85160B         8
#
# [149 rows x 2 columns]

# %%
a=df[df['Description'].str.contains('CAT*')]
CAT= a.groupby('StockCode')['Categoria'].nunique().reset_index()
CAT.columns = ['StockCode', 'Category']
CAT["Category"]=8
CAT
# Out:
#     StockCode  Category
# 0       10002         8
# 1       10080         8
# 2      10123G         8
# 3      10124G         8
# 4       11001         8
# ..        ...       ...
# 875    90162D         8
# 876  DCGS0041         8
# 877  DCGS0044         8
# 878  DCGS0062         8
# 879  DCGS0072         8
#
# [880 rows x 2 columns]

# %%
a=df[df['Description'].str.contains('PAINT*')]
PAINT= a.groupby('StockCode')['Categoria'].nunique().reset_index()
PAINT.columns = ['StockCode', 'Category']
PAINT["Category"]=10
PAINT
# Out:
#    StockCode  Category
# 0      21133        10
# 1      21136        10
# 2      21454        10
# 3      21455        10
# 4      21462        10
# 5      21823        10
# 6      21824        10
# 7      21825        10
# 8      22228        10
# 9      22229        10
# 10     22283        10
# 11     22335        10
# 12     22336        10
# 13     22337        10
# 14     22338        10
# 15     22339        10
# 16     22340        10
# 17     22341        10
# 18     22342        10
# 19     22492        10
# 20     22493        10
# 21     23210        10
# 22     23211        10
# 23     23212        10
# 24     23270        10
# 25     23440        10
# 26     23441        10
# 27     23442        10
# 28     75172        10
# 29    79144B        10
# 30    79144C        10
# 31     85212        10
# 32    90038A        10
# 33    90038B        10

# %%
a=df[df['Description'].str.contains('UMBRELLA*')]
UMB= a.groupby('StockCode')['Categoria'].nunique().reset_index()
UMB.columns = ['StockCode', 'Category']
UMB["Category"]=11
UMB
# Out:
#    StockCode  Category
# 0     15060B        11
# 1     15060b        11
# 2      20680        11
# 3      20681        11
# 4      20682        11
# 5      20683        11
# 6      20684        11
# 7      20686        11
# 8      21706        11
# 9      21707        11
# 10     21708        11
# 11     21709        11
# 12     21710        11
# 13     21711        11
# 14    85014A        11
# 15    85014B        11
# 16    85014C        11
# 17    85014D        11

# %%
a=df[df['Description'].str.contains('GLOVES*')]
GLO= a.groupby('StockCode')['Categoria'].nunique().reset_index()
GLO.columns = ['StockCode', 'Category']
GLO["Category"]=12
GLO
# Out:
#    StockCode  Category
# 0      20751        12
# 1      20752        12
# 2      20753        12
# 3      20754        12
# 4      20998        12
# 5      21041        12
# 6      21154        12
# 7      21836        12
# 8      22524        12
# 9      22525        12
# 10     35832        12
# 11    47559B        12
# 12    47559b        12
# 13    84798A        12
# 14    84798B        12
# 15    84798C        12

# %%
a=df[df['Description'].str.contains('GAME*')]
GAME= a.groupby('StockCode')['Categoria'].nunique().reset_index()
GAME.columns = ['StockCode', 'Category']
GAME["Category"]=13
GAME
# Out:
#    StockCode  Category
# 0     17011A        13
# 1     17011B        13
# 2     17011C        13
# 3     17011D        13
# 4     17011F        13
# 5     17012A        13
# 6     17012B        13
# 7     17012C        13
# 8     17012D        13
# 9     17012E        13
# 10    17012F        13
# 11    17013B        13
# 12    17013D        13
# 13    17013F        13
# 14    17014A        13
# 15    17014C        13
# 16    17014D        13
# 17    17014E        13
# 18    17014F        13
# 19     21791        13
# 20     21853        13
# 21     21854        13
# 22     21857        13
# 23     21860        13
# 24     21892        13
# 25     22814        13
# 26     23229        13
# 27     23570        13

# %%
a=df[df['Description'].str.contains('MUG*')]
MUG= a.groupby('StockCode')['Categoria'].nunique().reset_index()
MUG.columns = ['StockCode', 'Category']
MUG["Category"]=14
MUG
# Out:
#     StockCode  Category
# 0       20759        14
# 1       20765        14
# 2       20771        14
# 3       20777        14
# 4       20780        14
# ..        ...       ...
# 137    90040D        14
# 138    90120A        14
# 139    90120B        14
# 140    90120C        14
# 141    90120D        14
#
# [142 rows x 2 columns]

# %%
a=df[df['Description'].str.contains('CAKE*')]
CAKE= a.groupby('StockCode')['Categoria'].nunique().reset_index()
CAKE.columns = ['StockCode', 'Category']
CAKE["Category"]=15
CAKE
# Out:
#     StockCode  Category
# 0      15060B        15
# 1      15060b        15
# 2      16156S        15
# 3       21108        15
# 4       21109        15
# ..        ...       ...
# 121     84990        15
# 122     84991        15
# 123     84992        15
# 124     85216        15
# 125     85220        15
#
# [126 rows x 2 columns]

# %%
#a=df[df['Description'].str.contains('*')]
C= df.groupby('StockCode')['Categoria'].nunique().reset_index()
C.columns = ['StockCode', 'Category']
C["Category"]=1
C
# Out:
#          StockCode  Category
# 0            10002         1
# 1           10002R         1
# 2            10080         1
# 3            10109         1
# 4            10120         1
# ...            ...       ...
# 4715  gift_0001_60         1
# 4716  gift_0001_70         1
# 4717  gift_0001_80         1
# 4718  gift_0001_90         1
# 4719             m         1
#
# [4720 rows x 2 columns]

# %%
f= [Light, BAG, DOG, decoration, PEN, FLOWER, DESIGN, CAT, PAINT, UMB, GLO, GAME, MUG, CAKE, CHILD, C]
r=pd.concat(f)
r
e= r.groupby('StockCode')['Category'].max().reset_index()
e
# Out:
#          StockCode  Category
# 0            10002         8
# 1           10002R         6
# 2            10080         8
# 3            10109         6
# 4            10120         4
# ...            ...       ...
# 4715  gift_0001_60         1
# 4716  gift_0001_70         1
# 4717  gift_0001_80         1
# 4718  gift_0001_90         1
# 4719             m         1
#
# [4720 rows x 2 columns]

# %%
a=df[df['Description'].str.contains('BAG*')]
BAG= a.groupby('StockCode')['Categoria'].nunique().reset_index()
BAG.columns = ['StockCode', 'Category']
BAG["Category"]=3
BAG
# Out:
#      StockCode  Category
# 0        16053         3
# 1       16151A         3
# 2       16161G         3
# 3       16162L         3
# 4       16162M         3
# ..         ...       ...
# 482     90210B         3
# 483     90210C         3
# 484     90210D         3
# 485   DCGSSBOY         3
# 486  DCGSSGIRL         3
#
# [487 rows x 2 columns]

# %%
#cerco se c'è price =0
df[(df.Description==0)]
# Out:
#                Country  Customer ID Description  Invoice          InvoiceDate  \
# 2957    United Kingdom      17841.0           0   489781  2009-02-12 11:45:00
# 5218    United Kingdom      17841.0           0   489882  2009-02-12 16:22:00
# 13536   United Kingdom      17841.0           0   490716  2009-07-12 15:28:00
# 18277   United Kingdom      17841.0           0   491117  2009-09-12 14:59:00
# 18512   United Kingdom      17841.0           0   491142  2009-09-12 16:44:00
# ...                ...          ...         ...      ...                  ...
# 871424  United Kingdom      17841.0           0   581103  2011-07-12 11:58:00
# 872758  United Kingdom      17841.0           0   581203  2011-07-12 18:31:00
# 872759  United Kingdom      17841.0           0   581209  2011-07-12 18:35:00
# 874196  United Kingdom      17841.0           0   581234  2011-08-12 10:33:00
# 875581  United Kingdom      17841.0           0   581408  2011-08-12 14:06:00
#
# ...

# %%
#vedo quanti elementi vuoti abbiamo
df.isnull().sum()
# Out:
# Country        0
# Customer ID    0
# Description    0
# Invoice        0
# InvoiceDate    0
# Price          0
# Quantity       0
# StockCode      0
# Categoria      0
# dtype: int64

# %%
df = df.fillna(0)
df
# Out:
#                Country  Customer ID                          Description  \
# 0       United Kingdom      13085.0  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1       United Kingdom      13085.0                   PINK CHERRY LIGHTS
# 2       United Kingdom      13085.0                  WHITE CHERRY LIGHTS
# 3       United Kingdom      13085.0       STRAWBERRY CERAMIC TRINKET BOX
# 4       United Kingdom      13085.0           PINK DOUGHNUT TRINKET POT
# ...                ...          ...                                  ...
# 878447          France      12680.0          PACK OF 20 SPACEBOY NAPKINS
# 878448          France      12680.0         CHILDREN'S APRON DOLLY GIRL
# 878449          France      12680.0        CHILDRENS CUTLERY DOLLY GIRL
# 878450          France      12680.0      CHILDRENS CUTLERY CIRCUS PARADE
# 878451          France      12680.0        BAKING SET 9 PIECE RETROSPOT
#
#         Invoice          InvoiceDate  Price  Quantity StockCode
# ...

# %%
df.dtypes
# Out:
# Country         object
# Customer ID    float64
# Description     string
# Invoice          int64
# InvoiceDate     object
# Price          float64
# Quantity         int64
# StockCode       object
# dtype: object

# %%
df = df.astype({'Description': 'string'})

# %%
df["Categoria"] = 1

# %%
df
# Out:
#                Country  Customer ID                          Description  \
# 0       United Kingdom      13085.0  15CM CHRISTMAS GLASS BALL 20 LIGHTS
# 1       United Kingdom      13085.0                   PINK CHERRY LIGHTS
# 2       United Kingdom      13085.0                  WHITE CHERRY LIGHTS
# 3       United Kingdom      13085.0       STRAWBERRY CERAMIC TRINKET BOX
# 4       United Kingdom      13085.0           PINK DOUGHNUT TRINKET POT
# ...                ...          ...                                  ...
# 878447          France      12680.0          PACK OF 20 SPACEBOY NAPKINS
# 878448          France      12680.0         CHILDREN'S APRON DOLLY GIRL
# 878449          France      12680.0        CHILDRENS CUTLERY DOLLY GIRL
# 878450          France      12680.0      CHILDRENS CUTLERY CIRCUS PARADE
# 878451          France      12680.0        BAKING SET 9 PIECE RETROSPOT
#
#         Invoice          InvoiceDate  Price  Quantity StockCode  Categoria
# ...

# %%
df=e
df.to_csv('D:/Desktop/DataMining/CategoryFull.csv')

# %%
a=df[df['Description'],['Price']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5076/198126618.py in <module>
# ----> 1 a=df[df['Description'],['Price']]
#
# ~\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# ...

# %%
#DistinctPrice
#Price = df.groupby('StockCode')['Price'].nunique().reset_index()
#Price.columns = ['StockCode', 'Price']
#Price
a=df[['StockCode','Price']]
a
Price= a.groupby('StockCode')
#Price.columns = ['StockCode', 'Price']
#Price["Category"]=3
Price

# %%
a=df.groupby('StockCode')['Price'].unique().reset_index()
a
# Out:
#          StockCode                          Price
# 0            10002  [0.85, 1.7, 1.66, 0.72, 1.63]
# 1           10002R                   [5.17, 5.06]
# 2            10080              [0.85, 0.39, 0.0]
# 3            10109                         [0.42]
# 4            10120                   [0.21, 0.43]
# ...            ...                            ...
# 4715  gift_0001_60                          [0.0]
# 4716  gift_0001_70                          [0.0]
# 4717  gift_0001_80                          [0.0]
# 4718  gift_0001_90                          [0.0]
# 4719             m               [2.55, 3.4, 4.0]
#
# [4720 rows x 2 columns]

# %%
a.to_csv('D:/Desktop/DataMining/Price.csv')

# %%
df_09 = df[pd.DatetimeIndex(df['InvoiceDate']).year == 2009.0]
b=df_09.groupby('StockCode')['Price'].mean().reset_index()
b
# Out:
#          StockCode     Price
# 0            10002  0.991667
# 1           10002R  5.170000
# 2            10080  0.850000
# 3            10109  0.420000
# 4            10120  0.364000
# ...            ...       ...
# 2812             M  2.030000
# 2813          POST  4.316667
# 2814       TEST001  4.500000
# 2815       TEST002  0.500000
# 2816  gift_0001_80  0.000000
#
# [2817 rows x 2 columns]

# %%
df_10 = df[pd.DatetimeIndex(df['InvoiceDate']).year == 2010.0]
c=df_10.groupby('StockCode')['Price'].mean().reset_index()
c
# Out:
#          StockCode     Price
# 0            10002  1.001439
# 1           10002R  5.060000
# 2            10080  0.850000
# 3            10120  0.234444
# 4           10123C  0.814348
# ...            ...       ...
# 3831  gift_0001_60  0.000000
# 3832  gift_0001_70  0.000000
# 3833  gift_0001_80  0.000000
# 3834  gift_0001_90  0.000000
# 3835             m  3.010000
#
# [3836 rows x 2 columns]

# %%
#df_11 = df[pd.DatetimeIndex(df['InvoiceDate']).year == 2011.0]
#d=df_11.groupby('StockCode')['Price'].mean().reset_index()
d
# Out:
#          StockCode     Price
# 0            10002  1.019459
# 1            10080  0.393182
# 2            10120  0.210000
# 3           10123C  0.650000
# 4           10124A  0.420000
# ...            ...       ...
# 3657             M  1.539222
# 3658          PADS  0.000750
# 3659          POST  3.083143
# 3660  gift_0001_10  8.330000
# 3661  gift_0001_20  0.000000
#
# [3662 rows x 2 columns]

# %%
A=d.join(c, on='StockCode', lsuffix='11', rsuffix='10')
A
#Price=A.join(P, lsuffix='-')
#Price
#Price=pd.concat([b,c,d], axis=1, on='StockCode')
#Price
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16908/3726281936.py in <module>
# ----> 1 A=d.join(c, on='StockCode', lsuffix='11', rsuffix='10')
#       2 A
#       3 #Price=A.join(P, lsuffix='-')
#       4 #Price
#       5 #Price=pd.concat([b,c,d], axis=1, on='StockCode')
#
# ~\Anaconda\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    9097         5  K5  A5  NaN
#    9098         """
# -> 9099         return self._join_compat(
#    9100             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    9101         )
#
# ~\Anaconda\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    9128                     sort=sort,
#    9129                 )
# -> 9130             return merge(
#    9131                 self,
# ...

# %%
#P=b.join(c, lsuffix='09', rsuffix='10')
Price=P.leftjoin(d, lsuffix='11',rsuffix='11')
Price
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16908/1759415865.py in <module>
#       1 #P=b.join(c, lsuffix='09', rsuffix='10')
# ----> 2 Price=P.leftjoin(d, lsuffix='11',rsuffix='11')
#       3 Price
#
# ~\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'leftjoin'

# %%
df=Price
df.to_csv('D:/Desktop/DataMining/Price_years.csv')

# %%
# Out:
#        StockCode09   Price09 StockCode10   Price10 StockCode     Price
# 0            10002  0.991667       10002  1.001439     10002  1.019459
# 1           10002R  5.170000      10002R  5.060000     10080  0.393182
# 2            10080  0.850000       10080  0.850000     10120  0.210000
# 3            10109  0.420000       10120  0.234444    10123C  0.650000
# 4            10120  0.364000      10123C  0.814348    10124A  0.420000
# ...            ...       ...         ...       ...       ...       ...
# 2812             M  2.030000      84555A  2.926471    84508A  2.550000
# 2813          POST  4.316667      84558A  3.143645    84508B  2.550000
# 2814       TEST001  4.500000      84558a  5.910000    84508C  2.969130
# 2815       TEST002  0.500000      84559A  0.985254    84509A  4.427773
# 2816  gift_0001_80  0.000000      84559B  1.042889    84509B  3.708649
#
# [2817 rows x 6 columns]

# %%
Price.isnull().sum()
# Out:
# StockCode09    0
# Price09        0
# StockCode10    0
# Price10        0
# StockCode      0
# Price          0
# dtype: int64

# %%
df = pd.read_csv('D:/Desktop/DataMining/CategoryFull.csv', sep=',')
df
# Out:
#       Unnamed: 0     StockCode  Category
# 0              0         10002         8
# 1              1        10002R         6
# 2              2         10080         8
# 3              3         10109         6
# 4              4         10120         4
# ...          ...           ...       ...
# 4715        4715  gift_0001_60         1
# 4716        4716  gift_0001_70         1
# 4717        4717  gift_0001_80         1
# 4718        4718  gift_0001_90         1
# 4719        4719             m         1
#
# [4720 rows x 3 columns]

# %%
#Price10 = c.groupby('StockCode').nunique().reset_index()
#Price10
c
# Out:
#          StockCode     Price
# 0            10002  1.001439
# 1           10002R  5.060000
# 2            10080  0.850000
# 3            10120  0.234444
# 4           10123C  0.814348
# ...            ...       ...
# 3831  gift_0001_60  0.000000
# 3832  gift_0001_70  0.000000
# 3833  gift_0001_80  0.000000
# 3834  gift_0001_90  0.000000
# 3835             m  3.010000
#
# [3836 rows x 2 columns]

# %%
x=pd.merge(left=b, right=c,how='outer', on='StockCode')
x
# Out:
#          StockCode   Price_x   Price_y
# 0            10002  0.991667  1.001439
# 1           10002R  5.170000  5.060000
# 2            10080  0.850000  0.850000
# 3            10109  0.420000       NaN
# 4            10120  0.364000  0.234444
# ...            ...       ...       ...
# 4008  gift_0001_50       NaN  0.000000
# 4009  gift_0001_60       NaN  0.000000
# 4010  gift_0001_70       NaN  0.000000
# 4011  gift_0001_90       NaN  0.000000
# 4012             m       NaN  3.010000
#
# [4013 rows x 3 columns]

# %%
Price=pd.merge(left=x, right=d,how='outer', on='StockCode') 
Price.columns=['StockCode','Price09','Price10','Price11']
Price
# Out:
#          StockCode   Price09   Price10   Price11
# 0            10002  0.991667  1.001439  1.019459
# 1           10002R  5.170000  5.060000       NaN
# 2            10080  0.850000  0.850000  0.393182
# 3            10109  0.420000       NaN       NaN
# 4            10120  0.364000  0.234444  0.210000
# ...            ...       ...       ...       ...
# 4715        90183c       NaN       NaN  2.900000
# 4716         90191       NaN       NaN  2.950000
# 4717        90195A       NaN       NaN  2.950000
# 4718        90195B       NaN       NaN  2.950000
# 4719  BANK CHARGES       NaN       NaN  0.001000
#
# [4720 rows x 4 columns]

# %%
df=Price
df.to_csv('D:/Desktop/DataMining/PriceAnni.csv')

# %%
df = pd.read_csv('D:/Desktop/DataMining/item.csv', sep=',')
df
# Out:
#          StockCode  DistinctCust  TotItemBought  DistinctSession  AvgItemSess  \
# 0            10002           152           2597              314     8.270701
# 1           10002R             1              4                3     1.333333
# 2            10080            24            289               27    10.703704
# 3            10109             1              4                1     4.000000
# 4            10120            42            244               60     4.066667
# ...            ...           ...            ...              ...          ...
# 4715  gift_0001_60             1             13                2     6.500000
# 4716  gift_0001_70             1             12                2     6.000000
# 4717  gift_0001_80             1             12                2     6.000000
# 4718  gift_0001_90             1             12                2     6.000000
# 4719             m             1              5                4     1.250000
#
#       MeanItemMonth
# ...

# %%
Dataset=pd.merge(left=Price, right=df,how='outer', on='StockCode') 
Dataset
# Out:
#          StockCode   Price09   Price10   Price11  DistinctCust  TotItemBought  \
# 0            10002  0.991667  1.001439  1.019459           152           2597
# 1           10002R  5.170000  5.060000       NaN             1              4
# 2            10080  0.850000  0.850000  0.393182            24            289
# 3            10109  0.420000       NaN       NaN             1              4
# 4            10120  0.364000  0.234444  0.210000            42            244
# ...            ...       ...       ...       ...           ...            ...
# 4715        90183c       NaN       NaN  2.900000             1              1
# 4716         90191       NaN       NaN  2.950000             3             17
# 4717        90195A       NaN       NaN  2.950000             3              8
# 4718        90195B       NaN       NaN  2.950000             1              1
# 4719  BANK CHARGES       NaN       NaN  0.001000             1              1
#
# ...

# %%
df = pd.read_csv('D:/Desktop/DataMining/Categoryfull.csv', sep=',')
df
# Out:
#       Unnamed: 0     StockCode  Category
# 0              0         10002         8
# 1              1        10002R         6
# 2              2         10080         8
# 3              3         10109         6
# 4              4         10120         4
# ...          ...           ...       ...
# 4715        4715  gift_0001_60         1
# 4716        4716  gift_0001_70         1
# 4717        4717  gift_0001_80         1
# 4718        4718  gift_0001_90         1
# 4719        4719             m         1
#
# [4720 rows x 3 columns]

# %%
Data=pd.merge(left=Dataset, right=df,how='outer', on='StockCode') 
Data
# Out:
#          StockCode   Price09   Price10   Price11  DistinctCust  TotItemBought  \
# 0            10002  0.991667  1.001439  1.019459           152           2597
# 1           10002R  5.170000  5.060000       NaN             1              4
# 2            10080  0.850000  0.850000  0.393182            24            289
# 3            10109  0.420000       NaN       NaN             1              4
# 4            10120  0.364000  0.234444  0.210000            42            244
# ...            ...       ...       ...       ...           ...            ...
# 4715        90183c       NaN       NaN  2.900000             1              1
# 4716         90191       NaN       NaN  2.950000             3             17
# 4717        90195A       NaN       NaN  2.950000             3              8
# 4718        90195B       NaN       NaN  2.950000             1              1
# 4719  BANK CHARGES       NaN       NaN  0.001000             1              1
#
# ...

# %%
df=Data
df.to_csv('D:/Desktop/DataMining/Item.csv')
